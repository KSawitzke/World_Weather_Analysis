# %%
# import modules, dependencies, and API key
from citipy import citipy
import numpy as np
import pandas as pd
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-90, 90, size=2000)

# Pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for the cities
cities = []
# Get nearest cities
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 771

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | salinas
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | burica
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 1 | souillac
# Processing Record 9 of Set 1 | smithfield
# Processing Record 10 of Set 1 | tiznit
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | husavik
# Processing Record 13 of Set 1 | svetla nad sazavou
# Processing Record 14 of Set 1 | margate
# Processing Record 15 of Set 1 | guanica
# Processing Record 16 of Set 1 | aleksandrov gay
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | bambous virieux
# Processing Record 20 of Set 1 | ust-tsilma
# Processing Record 21 of Set 1 | cockburn town
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | clyde river
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | charlestown
# Processing Record 29 of Set 1 | les cayes
# Processing Record 30 of Set 1 | abu samrah
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | calais
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 35 of Set 1 | pedernales
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | torres
# Processing Record 38 of Set 1 | heinola
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | maniitsoq
# Processing Record 41 of Set 1 | adrar
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | sinnamary
# Processing Record 44 of Set 1 | boende
# Processing Record 45 of Set 1 | soria
# Processing Record 46 of Set 1 | vanersborg
# Processing Record 47 of Set 1 | pontes e lacerda
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | pailon
# Processing Record 50 of Set 1 | sistranda
# Processing Record 1 of Set 2 | pipri
# Processing Record 2 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 2 | anantapur
# Processing Record 4 of Set 2 | patrocinio
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | caravelas
# Processing Record 7 of Set 2 | sao paulo de olivenca
# Processing Record 8 of Set 2 | marsh harbour
# Processing Record 9 of Set 2 | jurado
# Processing Record 10 of Set 2 | lamu
# Processing Record 11 of Set 2 | zlobin
# Processing Record 12 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 13 of Set 2 | tessalit
# Processing Record 14 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 2 | westerland
# Processing Record 16 of Set 2 | port blair
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | inhambane
# Processing Record 19 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 20 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | buta
# Processing Record 23 of Set 2 | gao
# Processing Record 24 of Set 2 | los llanos de aridane
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | acarau
# Processing Record 28 of Set 2 | berlevag
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | montecchio maggiore
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | savannah bight
# Processing Record 34 of Set 2 | brigantine
# Processing Record 35 of Set 2 | hamilton
# Processing Record 36 of Set 2 | formosa
# Processing Record 37 of Set 2 | kaabong
# Processing Record 38 of Set 2 | asosa
# Processing Record 39 of Set 2 | naifaru
# Processing Record 40 of Set 2 | marevo
# Processing Record 41 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 2 | nirmal
# Processing Record 43 of Set 2 | santa rosa
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | jumla
# Processing Record 46 of Set 2 | saint george
# Processing Record 47 of Set 2 | gaoua
# Processing Record 48 of Set 2 | rodrigues alves
# Processing Record 49 of Set 2 | turukhansk
# Processing Record 50 of Set 2 | sikeston
# Processing Record 1 of Set 3 | hambantota
# Processing Record 2 of Set 3 | coquimbo
# Processing Record 3 of Set 3 | valparaiso
# Processing Record 4 of Set 3 | alto araguaia
# Processing Record 5 of Set 3 | ystad
# Processing Record 6 of Set 3 | olafsvik
# Processing Record 7 of Set 3 | port hawkesbury
# Processing Record 8 of Set 3 | la rioja
# Processing Record 9 of Set 3 | tigzirt
# Processing Record 10 of Set 3 | hendijan
# City not found. Skipping...
# Processing Record 11 of Set 3 | acajutla
# Processing Record 12 of Set 3 | mporokoso
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | qeshm
# Processing Record 15 of Set 3 | hofn
# Processing Record 16 of Set 3 | bereda
# Processing Record 17 of Set 3 | shirgaon
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | aksu
# Processing Record 20 of Set 3 | talnakh
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | codrington
# Processing Record 23 of Set 3 | moose factory
# Processing Record 24 of Set 3 | vardo
# Processing Record 25 of Set 3 | salalah
# Processing Record 26 of Set 3 | bandarbeyla
# Processing Record 27 of Set 3 | riachao das neves
# Processing Record 28 of Set 3 | manta
# Processing Record 29 of Set 3 | iqaluit
# Processing Record 30 of Set 3 | grand gaube
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | comodoro rivadavia
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | caucaia
# Processing Record 35 of Set 3 | bonfim
# Processing Record 36 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 3 | guia lopes da laguna
# Processing Record 38 of Set 3 | pangnirtung
# Processing Record 39 of Set 3 | beberibe
# Processing Record 40 of Set 3 | kavaratti
# Processing Record 41 of Set 3 | geraldton
# Processing Record 42 of Set 3 | antofagasta
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | didwana
# Processing Record 45 of Set 3 | bonthe
# Processing Record 46 of Set 3 | itarema
# Processing Record 47 of Set 3 | marzuq
# Processing Record 48 of Set 3 | longyearbyen
# Processing Record 49 of Set 3 | tarabuco
# Processing Record 50 of Set 3 | humaita
# Processing Record 1 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 4 | panjab
# Processing Record 3 of Set 4 | buribay
# Processing Record 4 of Set 4 | oia
# Processing Record 5 of Set 4 | luderitz
# Processing Record 6 of Set 4 | buraydah
# Processing Record 7 of Set 4 | mutis
# Processing Record 8 of Set 4 | nsanje
# Processing Record 9 of Set 4 | vila franca do campo
# Processing Record 10 of Set 4 | sisimiut
# Processing Record 11 of Set 4 | mecca
# Processing Record 12 of Set 4 | chama
# Processing Record 13 of Set 4 | vila velha
# Processing Record 14 of Set 4 | faya
# Processing Record 15 of Set 4 | nuristan
# Processing Record 16 of Set 4 | bauchi
# Processing Record 17 of Set 4 | ouesso
# Processing Record 18 of Set 4 | penzance
# Processing Record 19 of Set 4 | agirish
# Processing Record 20 of Set 4 | shache
# Processing Record 21 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 4 | mwingi
# Processing Record 23 of Set 4 | paamiut
# Processing Record 24 of Set 4 | goundam
# Processing Record 25 of Set 4 | necochea
# Processing Record 26 of Set 4 | ajaccio
# Processing Record 27 of Set 4 | bridlington
# Processing Record 28 of Set 4 | usinsk
# Processing Record 29 of Set 4 | san pedro de macoris
# Processing Record 30 of Set 4 | bathsheba
# Processing Record 31 of Set 4 | avila
# Processing Record 32 of Set 4 | vetel
# Processing Record 33 of Set 4 | matay
# Processing Record 34 of Set 4 | puerto narino
# Processing Record 35 of Set 4 | ancud
# Processing Record 36 of Set 4 | kankon
# Processing Record 37 of Set 4 | tasiilaq
# Processing Record 38 of Set 4 | omboue
# Processing Record 39 of Set 4 | wajir
# Processing Record 40 of Set 4 | karla
# Processing Record 41 of Set 4 | kibala
# Processing Record 42 of Set 4 | ust-shonosha
# Processing Record 43 of Set 4 | brae
# Processing Record 44 of Set 4 | stromness
# Processing Record 45 of Set 4 | turayf
# Processing Record 46 of Set 4 | hensall
# Processing Record 47 of Set 4 | paslek
# Processing Record 48 of Set 4 | sencha
# Processing Record 49 of Set 4 | nouadhibou
# Processing Record 50 of Set 4 | nurobod
# Processing Record 1 of Set 5 | tahta
# Processing Record 2 of Set 5 | prado
# Processing Record 3 of Set 5 | altea
# Processing Record 4 of Set 5 | panorama
# Processing Record 5 of Set 5 | moba
# Processing Record 6 of Set 5 | palafrugell
# Processing Record 7 of Set 5 | ilebo
# Processing Record 8 of Set 5 | ramachandrapuram
# Processing Record 9 of Set 5 | rio gallegos
# Processing Record 10 of Set 5 | sorland
# Processing Record 11 of Set 5 | angoche
# Processing Record 12 of Set 5 | zhanaozen
# Processing Record 13 of Set 5 | wajid
# Processing Record 14 of Set 5 | bhag
# Processing Record 15 of Set 5 | coihaique
# Processing Record 16 of Set 5 | dudinka
# Processing Record 17 of Set 5 | carauari
# Processing Record 18 of Set 5 | kousseri
# Processing Record 19 of Set 5 | gambissara
# Processing Record 20 of Set 5 | alexandria
# Processing Record 21 of Set 5 | gornopravdinsk
# Processing Record 22 of Set 5 | chake chake
# Processing Record 23 of Set 5 | harper
# Processing Record 24 of Set 5 | alta floresta
# Processing Record 25 of Set 5 | manzil tamim
# City not found. Skipping...
# Processing Record 26 of Set 5 | bilma
# Processing Record 27 of Set 5 | zuenoula
# Processing Record 28 of Set 5 | narsaq
# Processing Record 29 of Set 5 | sao felix do xingu
# Processing Record 30 of Set 5 | tutoia
# Processing Record 31 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 5 | yining
# Processing Record 33 of Set 5 | sharjah
# Processing Record 34 of Set 5 | gambela
# Processing Record 35 of Set 5 | aksarka
# Processing Record 36 of Set 5 | korla
# Processing Record 37 of Set 5 | kruisfontein
# Processing Record 38 of Set 5 | ljubinje
# Processing Record 39 of Set 5 | pakaur
# Processing Record 40 of Set 5 | ugoofaaru
# Processing Record 41 of Set 5 | iranshahr
# Processing Record 42 of Set 5 | nordhausen
# Processing Record 43 of Set 5 | tombouctou
# Processing Record 44 of Set 5 | saint anthony
# Processing Record 45 of Set 5 | destin
# Processing Record 46 of Set 5 | chapais
# Processing Record 47 of Set 5 | birao
# Processing Record 48 of Set 5 | itapora
# Processing Record 49 of Set 5 | hun
# Processing Record 50 of Set 5 | massaguet
# Processing Record 1 of Set 6 | ponta do sol
# Processing Record 2 of Set 6 | coihueco
# Processing Record 3 of Set 6 | kashan
# Processing Record 4 of Set 6 | kerman
# Processing Record 5 of Set 6 | malinovskiy
# Processing Record 6 of Set 6 | aras
# Processing Record 7 of Set 6 | quatre cocos
# Processing Record 8 of Set 6 | calderitas
# Processing Record 9 of Set 6 | waddan
# Processing Record 10 of Set 6 | quartucciu
# Processing Record 11 of Set 6 | pizarro
# Processing Record 12 of Set 6 | middletown
# Processing Record 13 of Set 6 | warri
# Processing Record 14 of Set 6 | keti bandar
# Processing Record 15 of Set 6 | rudbar
# Processing Record 16 of Set 6 | chabahar
# Processing Record 17 of Set 6 | feijo
# Processing Record 18 of Set 6 | saint-pierre
# Processing Record 19 of Set 6 | itapaci
# Processing Record 20 of Set 6 | general pico
# Processing Record 21 of Set 6 | kralendijk
# Processing Record 22 of Set 6 | road town
# Processing Record 23 of Set 6 | ostrovnoy
# Processing Record 24 of Set 6 | viedma
# Processing Record 25 of Set 6 | raudeberg
# Processing Record 26 of Set 6 | kapchorwa
# Processing Record 27 of Set 6 | sao joao da barra
# Processing Record 28 of Set 6 | san ignacio
# Processing Record 29 of Set 6 | bolobo
# Processing Record 30 of Set 6 | bardiyah
# Processing Record 31 of Set 6 | batticaloa
# Processing Record 32 of Set 6 | gurlan
# Processing Record 33 of Set 6 | saint-joseph
# Processing Record 34 of Set 6 | challans
# Processing Record 35 of Set 6 | rio grande
# Processing Record 36 of Set 6 | novouzensk
# Processing Record 37 of Set 6 | asfi
# Processing Record 38 of Set 6 | montepuez
# Processing Record 39 of Set 6 | atar
# Processing Record 40 of Set 6 | chincha alta
# Processing Record 41 of Set 6 | deseronto
# Processing Record 42 of Set 6 | krasnoselkup
# Processing Record 43 of Set 6 | jadu
# Processing Record 44 of Set 6 | chitral
# Processing Record 45 of Set 6 | khash
# Processing Record 46 of Set 6 | khudumelapye
# Processing Record 47 of Set 6 | miraflores
# Processing Record 48 of Set 6 | lagoa
# Processing Record 49 of Set 6 | remedios
# Processing Record 50 of Set 6 | shepetivka
# Processing Record 1 of Set 7 | santiago
# Processing Record 2 of Set 7 | ariano irpino
# Processing Record 3 of Set 7 | tabou
# Processing Record 4 of Set 7 | geilo
# Processing Record 5 of Set 7 | kharhial
# Processing Record 6 of Set 7 | kalaleh
# Processing Record 7 of Set 7 | karasuk
# Processing Record 8 of Set 7 | umm lajj
# Processing Record 9 of Set 7 | onega
# Processing Record 10 of Set 7 | bayonet point
# Processing Record 11 of Set 7 | ormara
# Processing Record 12 of Set 7 | kytlym
# City not found. Skipping...
# Processing Record 13 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 7 | iskateley
# Processing Record 15 of Set 7 | jaleswar
# Processing Record 16 of Set 7 | bongandanga
# Processing Record 17 of Set 7 | maxixe
# Processing Record 18 of Set 7 | puerto maldonado
# Processing Record 19 of Set 7 | darnah
# Processing Record 20 of Set 7 | rumonge
# Processing Record 21 of Set 7 | zwedru
# Processing Record 22 of Set 7 | aybak
# City not found. Skipping...
# Processing Record 23 of Set 7 | san cristobal
# Processing Record 24 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 7 | puerto colombia
# Processing Record 26 of Set 7 | olinda
# Processing Record 27 of Set 7 | bull savanna
# Processing Record 28 of Set 7 | sao filipe
# Processing Record 29 of Set 7 | san andres
# Processing Record 30 of Set 7 | tromso
# Processing Record 31 of Set 7 | galle
# Processing Record 32 of Set 7 | pangody
# Processing Record 33 of Set 7 | havre-saint-pierre
# Processing Record 34 of Set 7 | nador
# Processing Record 35 of Set 7 | gazojak
# Processing Record 36 of Set 7 | ambagarh chauki
# Processing Record 37 of Set 7 | vredendal
# Processing Record 38 of Set 7 | comarapa
# Processing Record 39 of Set 7 | cayenne
# Processing Record 40 of Set 7 | palencia
# Processing Record 41 of Set 7 | fuerte olimpo
# Processing Record 42 of Set 7 | bonavista
# Processing Record 43 of Set 7 | voyvozh
# Processing Record 44 of Set 7 | hobyo
# Processing Record 45 of Set 7 | vestmanna
# Processing Record 46 of Set 7 | puerto carreno
# Processing Record 47 of Set 7 | rudsar
# Processing Record 48 of Set 7 | cabedelo
# Processing Record 49 of Set 7 | touros
# Processing Record 50 of Set 7 | den helder
# Processing Record 1 of Set 8 | kalmunai
# Processing Record 2 of Set 8 | hole narsipur
# Processing Record 3 of Set 8 | awjilah
# Processing Record 4 of Set 8 | salisbury
# Processing Record 5 of Set 8 | hit
# Processing Record 6 of Set 8 | san pedro
# Processing Record 7 of Set 8 | limon
# Processing Record 8 of Set 8 | mudyuga
# City not found. Skipping...
# Processing Record 9 of Set 8 | port-gentil
# Processing Record 10 of Set 8 | tafresh
# Processing Record 11 of Set 8 | klaksvik
# Processing Record 12 of Set 8 | laguna
# Processing Record 13 of Set 8 | suoyarvi
# Processing Record 14 of Set 8 | sault sainte marie
# Processing Record 15 of Set 8 | barabinsk
# Processing Record 16 of Set 8 | kaniv
# Processing Record 17 of Set 8 | kedougou
# Processing Record 18 of Set 8 | yuty
# Processing Record 19 of Set 8 | clarence town
# Processing Record 20 of Set 8 | bagotville
# Processing Record 21 of Set 8 | zaltan
# Processing Record 22 of Set 8 | gamba
# Processing Record 23 of Set 8 | sandnessjoen
# Processing Record 24 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 8 | mwinilunga
# Processing Record 26 of Set 8 | alabaster
# Processing Record 27 of Set 8 | guarapari
# Processing Record 28 of Set 8 | zhezkazgan
# Processing Record 29 of Set 8 | edd
# Processing Record 30 of Set 8 | killybegs
# Processing Record 31 of Set 8 | nazilli
# Processing Record 32 of Set 8 | wattegama
# Processing Record 33 of Set 8 | boddam
# Processing Record 34 of Set 8 | aswan
# Processing Record 35 of Set 8 | aripuana
# Processing Record 36 of Set 8 | barinas
# Processing Record 37 of Set 8 | kabalo
# Processing Record 38 of Set 8 | opobo
# City not found. Skipping...
# Processing Record 39 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 40 of Set 8 | visnes
# Processing Record 41 of Set 8 | puerto cabezas
# Processing Record 42 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 43 of Set 8 | hammerfest
# Processing Record 44 of Set 8 | walvis bay
# Processing Record 45 of Set 8 | urucara
# Processing Record 46 of Set 8 | chernelytsya
# Processing Record 47 of Set 8 | cotacachi
# Processing Record 48 of Set 8 | camacha
# Processing Record 49 of Set 8 | nanortalik
# Processing Record 50 of Set 8 | siderno
# Processing Record 1 of Set 9 | saint-louis
# Processing Record 2 of Set 9 | palakkad
# Processing Record 3 of Set 9 | canico
# Processing Record 4 of Set 9 | meulaboh
# Processing Record 5 of Set 9 | fort atkinson
# Processing Record 6 of Set 9 | venancio aires
# Processing Record 7 of Set 9 | iquique
# Processing Record 8 of Set 9 | bama
# Processing Record 9 of Set 9 | artyom
# Processing Record 10 of Set 9 | brokopondo
# Processing Record 11 of Set 9 | rocha
# Processing Record 12 of Set 9 | bay city
# Processing Record 13 of Set 9 | muros
# Processing Record 14 of Set 9 | sarny
# Processing Record 15 of Set 9 | marystown
# Processing Record 16 of Set 9 | polczyn-zdroj
# Processing Record 17 of Set 9 | planaltina
# Processing Record 18 of Set 9 | tevriz
# Processing Record 19 of Set 9 | stephenville
# Processing Record 20 of Set 9 | alibag
# Processing Record 21 of Set 9 | grindavik
# Processing Record 22 of Set 9 | matagami
# Processing Record 23 of Set 9 | menongue
# Processing Record 24 of Set 9 | saint-francois
# Processing Record 25 of Set 9 | eirunepe
# Processing Record 26 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 27 of Set 9 | opochka
# Processing Record 28 of Set 9 | sao jose do rio pardo
# Processing Record 29 of Set 9 | athmallik
# Processing Record 30 of Set 9 | gobabis
# Processing Record 31 of Set 9 | hillside
# Processing Record 32 of Set 9 | serenje
# Processing Record 33 of Set 9 | julio de castilhos
# Processing Record 34 of Set 9 | domoni
# Processing Record 35 of Set 9 | mahajanga
# Processing Record 36 of Set 9 | nyalikungu
# Processing Record 37 of Set 9 | qaqortoq
# Processing Record 38 of Set 9 | tsaratanana
# Processing Record 39 of Set 9 | phalaborwa
# Processing Record 40 of Set 9 | sukhumi
# Processing Record 41 of Set 9 | saint leonard
# Processing Record 42 of Set 9 | monte azul paulista
# Processing Record 43 of Set 9 | kargil
# Processing Record 44 of Set 9 | karakol
# Processing Record 45 of Set 9 | taltal
# Processing Record 46 of Set 9 | kulhudhuffushi
# Processing Record 47 of Set 9 | springdale
# Processing Record 48 of Set 9 | gravdal
# Processing Record 49 of Set 9 | olocuilta
# Processing Record 50 of Set 9 | praia
# Processing Record 1 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 10 | kangaatsiaq
# Processing Record 3 of Set 10 | soroti
# Processing Record 4 of Set 10 | yekaterinovka
# Processing Record 5 of Set 10 | halifax
# Processing Record 6 of Set 10 | yalova
# Processing Record 7 of Set 10 | padre bernardo
# Processing Record 8 of Set 10 | sidi ali
# Processing Record 9 of Set 10 | wismar
# Processing Record 10 of Set 10 | arlit
# Processing Record 11 of Set 10 | surgut
# Processing Record 12 of Set 10 | dolores
# Processing Record 13 of Set 10 | phalombe
# Processing Record 14 of Set 10 | itaporanga
# Processing Record 15 of Set 10 | gat
# Processing Record 16 of Set 10 | fraserburgh
# Processing Record 17 of Set 10 | rantoul
# Processing Record 18 of Set 10 | siedlce
# Processing Record 19 of Set 10 | urubicha
# Processing Record 20 of Set 10 | paranaiba
# Processing Record 21 of Set 10 | maturin
# Processing Record 22 of Set 10 | oswego
# Processing Record 23 of Set 10 | luau
# Processing Record 24 of Set 10 | ler
# Processing Record 25 of Set 10 | starosubkhangulovo
# Processing Record 26 of Set 10 | athy
# Processing Record 27 of Set 10 | sovetskiy
# Processing Record 28 of Set 10 | ouagadougou
# Processing Record 29 of Set 10 | damghan
# Processing Record 30 of Set 10 | miandoab
# Processing Record 31 of Set 10 | kayerkan
# Processing Record 32 of Set 10 | puerto del rosario
# Processing Record 33 of Set 10 | morant bay
# Processing Record 34 of Set 10 | naryan-mar
# Processing Record 35 of Set 10 | petropavlivka
# Processing Record 36 of Set 10 | manono
# Processing Record 37 of Set 10 | thinadhoo
# Processing Record 38 of Set 10 | andra
# Processing Record 39 of Set 10 | warmbad
# Processing Record 40 of Set 10 | lovozero
# Processing Record 41 of Set 10 | pisco
# Processing Record 42 of Set 10 | sao jose da coroa grande
# Processing Record 43 of Set 10 | san gavino monreale
# Processing Record 44 of Set 10 | volchansk
# Processing Record 45 of Set 10 | delta del tigre
# Processing Record 46 of Set 10 | atocha
# Processing Record 47 of Set 10 | bahia honda
# Processing Record 48 of Set 10 | coro
# Processing Record 49 of Set 10 | lumeje
# Processing Record 50 of Set 10 | chissamba
# Processing Record 1 of Set 11 | boda
# Processing Record 2 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 11 | bria
# Processing Record 4 of Set 11 | bubaque
# Processing Record 5 of Set 11 | gazli
# Processing Record 6 of Set 11 | beswan
# Processing Record 7 of Set 11 | antalaha
# Processing Record 8 of Set 11 | abu dhabi
# Processing Record 9 of Set 11 | trincomalee
# Processing Record 10 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 11 | luziania
# Processing Record 12 of Set 11 | manali
# Processing Record 13 of Set 11 | doha
# Processing Record 14 of Set 11 | talah
# City not found. Skipping...
# Processing Record 15 of Set 11 | misratah
# Processing Record 16 of Set 11 | tanout
# Processing Record 17 of Set 11 | urdoma
# Processing Record 18 of Set 11 | sainte-marie
# Processing Record 19 of Set 11 | general roca
# Processing Record 20 of Set 11 | ous
# Processing Record 21 of Set 11 | eenhana
# Processing Record 22 of Set 11 | ndele
# Processing Record 23 of Set 11 | mbengwi
# Processing Record 24 of Set 11 | henties bay
# Processing Record 25 of Set 11 | kaltenkirchen
# Processing Record 26 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 27 of Set 11 | horuphav
# Processing Record 28 of Set 11 | riyadh
# Processing Record 29 of Set 11 | burgeo
# Processing Record 30 of Set 11 | marigot
# Processing Record 31 of Set 11 | havoysund
# Processing Record 32 of Set 11 | oranjemund
# Processing Record 33 of Set 11 | jiwani
# Processing Record 34 of Set 11 | loandjili
# Processing Record 35 of Set 11 | ajdabiya
# Processing Record 36 of Set 11 | le moule
# Processing Record 37 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 11 | namibe
# Processing Record 39 of Set 11 | santo tomas
# Processing Record 40 of Set 11 | krasnoshchekovo
# Processing Record 41 of Set 11 | muromtsevo
# Processing Record 42 of Set 11 | veraval
# Processing Record 43 of Set 11 | yanam
# Processing Record 44 of Set 11 | puerto rico
# Processing Record 45 of Set 11 | slavutych
# Processing Record 46 of Set 11 | lyubech
# Processing Record 47 of Set 11 | wankaner
# Processing Record 48 of Set 11 | najran
# Processing Record 49 of Set 11 | irtyshskiy
# Processing Record 50 of Set 11 | sur
# Processing Record 1 of Set 12 | ostersund
# Processing Record 2 of Set 12 | leesburg
# Processing Record 3 of Set 12 | gewane
# Processing Record 4 of Set 12 | necocli
# Processing Record 5 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 6 of Set 12 | una
# Processing Record 7 of Set 12 | ocala
# Processing Record 8 of Set 12 | lamentin
# Processing Record 9 of Set 12 | inta
# Processing Record 10 of Set 12 | dwarka
# Processing Record 11 of Set 12 | maniwaki
# Processing Record 12 of Set 12 | saint-augustin
# Processing Record 13 of Set 12 | reconquista
# Processing Record 14 of Set 12 | nuuk
# Processing Record 15 of Set 12 | pampas
# Processing Record 16 of Set 12 | huarmey
# Processing Record 17 of Set 12 | tucuma
# Processing Record 18 of Set 12 | lerwick
# Processing Record 19 of Set 12 | amapa
# Processing Record 20 of Set 12 | deder
# Processing Record 21 of Set 12 | luquillo
# Processing Record 22 of Set 12 | trairi
# Processing Record 23 of Set 12 | san jose
# Processing Record 24 of Set 12 | kindu
# Processing Record 25 of Set 12 | colesberg
# Processing Record 26 of Set 12 | andros town
# Processing Record 27 of Set 12 | bloemhof
# Processing Record 28 of Set 12 | tres arroyos
# Processing Record 29 of Set 12 | mehamn
# Processing Record 30 of Set 12 | gidam
# Processing Record 31 of Set 12 | westport
# Processing Record 32 of Set 12 | capreol
# Processing Record 33 of Set 12 | kula
# Processing Record 34 of Set 12 | beloha
# Processing Record 35 of Set 12 | bandiagara
# Processing Record 36 of Set 12 | lindi
# Processing Record 37 of Set 12 | bay roberts
# Processing Record 38 of Set 12 | noratus
# Processing Record 39 of Set 12 | jalu
# Processing Record 40 of Set 12 | paranhos
# Processing Record 41 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 12 | key largo
# Processing Record 43 of Set 12 | oussouye
# Processing Record 44 of Set 12 | ongandjera
# Processing Record 45 of Set 12 | jaguaquara
# Processing Record 46 of Set 12 | garowe
# Processing Record 47 of Set 12 | ambovombe
# Processing Record 48 of Set 12 | sudislavl
# Processing Record 49 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 12 | placido de castro
# Processing Record 1 of Set 13 | shu
# Processing Record 2 of Set 13 | phaltan
# Processing Record 3 of Set 13 | belyy yar
# Processing Record 4 of Set 13 | pemba
# Processing Record 5 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 13 | mpika
# Processing Record 7 of Set 13 | taguatinga
# Processing Record 8 of Set 13 | lima
# Processing Record 9 of Set 13 | nioro
# Processing Record 10 of Set 13 | talas
# Processing Record 11 of Set 13 | khandbari
# Processing Record 12 of Set 13 | muravlenko
# Processing Record 13 of Set 13 | cordoba
# Processing Record 14 of Set 13 | hualmay
# Processing Record 15 of Set 13 | agadez
# Processing Record 16 of Set 13 | ebeltoft
# Processing Record 17 of Set 13 | richards bay
# Processing Record 18 of Set 13 | sydney mines
# Processing Record 19 of Set 13 | labrea
# Processing Record 20 of Set 13 | igarka
# Processing Record 21 of Set 13 | skibbereen
# Processing Record 22 of Set 13 | kjollefjord
# Processing Record 23 of Set 13 | worcester
# Processing Record 24 of Set 13 | eyl
# Processing Record 25 of Set 13 | kpandu
# Processing Record 26 of Set 13 | tarrafal
# Processing Record 27 of Set 13 | tukrah
# Processing Record 28 of Set 13 | ijui
# Processing Record 29 of Set 13 | pompeu
# Processing Record 30 of Set 13 | kanye
# Processing Record 31 of Set 13 | corn island
# Processing Record 32 of Set 13 | korem
# Processing Record 33 of Set 13 | othaya
# Processing Record 34 of Set 13 | puerto suarez
# Processing Record 35 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 36 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 37 of Set 13 | alghero
# Processing Record 38 of Set 13 | balkanabat
# Processing Record 39 of Set 13 | severouralsk
# Processing Record 40 of Set 13 | bharatpur
# Processing Record 41 of Set 13 | praia da vitoria
# Processing Record 42 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 13 | goma
# Processing Record 44 of Set 13 | corrente
# Processing Record 45 of Set 13 | calabozo
# Processing Record 46 of Set 13 | razole
# Processing Record 47 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 13 | riohacha
# Processing Record 49 of Set 13 | plettenberg bay
# Processing Record 50 of Set 13 | banatsko novo selo
# Processing Record 1 of Set 14 | yabassi
# Processing Record 2 of Set 14 | mumbwa
# Processing Record 3 of Set 14 | cascais
# Processing Record 4 of Set 14 | carutapera
# Processing Record 5 of Set 14 | krasnoye
# Processing Record 6 of Set 14 | obidos
# Processing Record 7 of Set 14 | mocuba
# Processing Record 8 of Set 14 | lasa
# Processing Record 9 of Set 14 | peruibe
# Processing Record 10 of Set 14 | itupiranga
# Processing Record 11 of Set 14 | koutiala
# Processing Record 12 of Set 14 | constitucion
# Processing Record 13 of Set 14 | aranos
# Processing Record 14 of Set 14 | folldal
# Processing Record 15 of Set 14 | puerto ayacucho
# Processing Record 16 of Set 14 | crowthorne
# Processing Record 17 of Set 14 | paita
# Processing Record 18 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 14 | helena
# Processing Record 20 of Set 14 | favara
# Processing Record 21 of Set 14 | vestmannaeyjar
# Processing Record 22 of Set 14 | lentini
# Processing Record 23 of Set 14 | kishtwar
# Processing Record 24 of Set 14 | terrasini
# Processing Record 25 of Set 14 | natal
# Processing Record 26 of Set 14 | springbok
# Processing Record 27 of Set 14 | noamundi
# Processing Record 28 of Set 14 | abalak
# Processing Record 29 of Set 14 | jardim
# Processing Record 30 of Set 14 | altamira
# Processing Record 31 of Set 14 | lebyazhye
# Processing Record 32 of Set 14 | parnaiba
# Processing Record 33 of Set 14 | pimentel
# Processing Record 34 of Set 14 | ampanihy
# Processing Record 35 of Set 14 | sapouy
# Processing Record 36 of Set 14 | panaba
# Processing Record 37 of Set 14 | mudkhed
# Processing Record 38 of Set 14 | maragogi
# Processing Record 39 of Set 14 | abnub
# Processing Record 40 of Set 14 | kemijarvi
# Processing Record 41 of Set 14 | teruel
# Processing Record 42 of Set 14 | iralaya
# Processing Record 43 of Set 14 | zhuravky
# Processing Record 44 of Set 14 | boston
# Processing Record 45 of Set 14 | camacupa
# Processing Record 46 of Set 14 | mbabane
# Processing Record 47 of Set 14 | biltine
# Processing Record 48 of Set 14 | severnoye
# Processing Record 49 of Set 14 | rehnan
# Processing Record 50 of Set 14 | umm kaddadah
# Processing Record 1 of Set 15 | svetlogorsk
# Processing Record 2 of Set 15 | nordfjordeid
# Processing Record 3 of Set 15 | aliwal north
# Processing Record 4 of Set 15 | wamba
# Processing Record 5 of Set 15 | bunda
# Processing Record 6 of Set 15 | ilhabela
# Processing Record 7 of Set 15 | gayeri
# Processing Record 8 of Set 15 | alanya
# Processing Record 9 of Set 15 | rosario
# Processing Record 10 of Set 15 | deep river
# Processing Record 11 of Set 15 | yurginskoye
# Processing Record 12 of Set 15 | parati
# Processing Record 13 of Set 15 | teofilo otoni
# Processing Record 14 of Set 15 | zabol
# Processing Record 15 of Set 15 | kikwit
# Processing Record 16 of Set 15 | tolosa
# Processing Record 17 of Set 15 | gracac
# Processing Record 18 of Set 15 | corbelia
# Processing Record 19 of Set 15 | denia
# Processing Record 20 of Set 15 | gulshat
# City not found. Skipping...
# Processing Record 21 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 22 of Set 15 | san
# Processing Record 23 of Set 15 | dingle
# Processing Record 24 of Set 15 | staryy nadym
# Processing Record 25 of Set 15 | leh
# Processing Record 26 of Set 15 | westpunt
# City not found. Skipping...
# Processing Record 27 of Set 15 | vysha
# Processing Record 28 of Set 15 | maarianhamina
# Processing Record 29 of Set 15 | rawson
# Processing Record 30 of Set 15 | sergeyevka
# Processing Record 31 of Set 15 | skelleftea
# Processing Record 32 of Set 15 | ormond beach
# Processing Record 33 of Set 15 | soubre
# Processing Record 34 of Set 15 | san juan
# Processing Record 35 of Set 15 | kempele
# Processing Record 36 of Set 15 | maceio
# Processing Record 37 of Set 15 | srivardhan
# Processing Record 38 of Set 15 | kinshasa
# Processing Record 39 of Set 15 | salinopolis
# Processing Record 40 of Set 15 | lannion
# Processing Record 41 of Set 15 | sept-iles
# Processing Record 42 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 15 | cumberland
# Processing Record 44 of Set 15 | bekes
# Processing Record 45 of Set 15 | cuamba
# Processing Record 46 of Set 15 | sokolo
# Processing Record 47 of Set 15 | filadelfia
# Processing Record 48 of Set 15 | malatya
# Processing Record 49 of Set 15 | borba
# Processing Record 50 of Set 15 | teguise
# Processing Record 1 of Set 16 | riacho de santana
# Processing Record 2 of Set 16 | shihezi
# Processing Record 3 of Set 16 | olavarria
# Processing Record 4 of Set 16 | yurimaguas
# Processing Record 5 of Set 16 | osakarovka
# Processing Record 6 of Set 16 | tocopilla
# Processing Record 7 of Set 16 | puerto leguizamo
# Processing Record 8 of Set 16 | fort wellington
# Processing Record 9 of Set 16 | kaspiyskiy
# Processing Record 10 of Set 16 | kasama
# Processing Record 11 of Set 16 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 16 | goiana
# Processing Record 13 of Set 16 | luena
# Processing Record 14 of Set 16 | abha
# Processing Record 15 of Set 16 | bogo
# Processing Record 16 of Set 16 | the valley
# Processing Record 17 of Set 16 | sao gabriel da cachoeira
# Processing Record 18 of Set 16 | tikapur
# Processing Record 19 of Set 16 | markdorf
# Processing Record 20 of Set 16 | tamale
# Processing Record 21 of Set 16 | sakaraha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0       Salinas      US  2022-04-11 00:24:45  36.6777 -121.6555     72.01
# 1      Hermanus      ZA  2022-04-11 00:24:45 -34.4187   19.2345     62.80
# 2     Hithadhoo      MV  2022-04-11 00:23:36  -0.6000   73.0833     83.53
# 3    Bredasdorp      ZA  2022-04-11 00:24:45 -34.5322   20.0403     61.97
# 4   Port Alfred      ZA  2022-04-11 00:24:46 -33.5906   26.8910     65.17
# 5      Souillac      MU  2022-04-11 00:24:46 -20.5167   57.5167     77.38
# 6    Smithfield      US  2022-04-11 00:24:46  41.9220  -71.5495     47.46
# 7        Tiznit      MA  2022-04-11 00:24:47  29.5833   -9.5000     64.20
# 8  Punta Arenas      CL  2022-04-11 00:24:16 -53.1500  -70.9167     44.71
# 9       Husavik      IS  2022-04-11 00:24:47  66.0449  -17.3389     30.67
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        53           0       18.41           clear sky
# 1        90           5       11.50           clear sky
# 2        67          17       13.27          few clouds
# 3        94          13        5.88          few clouds
# 4        87         100        5.01     overcast clouds
# 5        78          40       14.97          light rain
# 6        54         100        8.05     overcast clouds
# 7        63          39        1.99    scattered clouds
# 8        81          75        4.61       broken clouds
# 9        84         100        0.65     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
